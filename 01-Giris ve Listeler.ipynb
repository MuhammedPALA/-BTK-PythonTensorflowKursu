# %% [markdown]
# Hadi Başlayalım 23.07.2025

# %% [markdown]
# Temel Fonksiyonlar

# %%
mesaj = "Merhaba"
mesaj1 ="Dünya"
isim = "Ali"
yas = "20"

# %%
print(mesaj + " " + mesaj1)
# Out:
# Merhaba Dünya

# %%
#İndeks alma
print(mesaj[0])
#burda da tersten indeks almak için kullanılır
print(mesaj[-1])
# Out:
# M
# a

# %%
#print demesek de anaconda anlıyor ama bir hücrede birden fazla çıktı alacaksan print kullanman gerek yoksa sadece son çıktıyı alıyor 
mesaj[0]
# Out:
# 'M'

# %% [markdown]
# Slicing - Strde kesme

# %%
#ilk 2 elemanı alma sonrasını al -2 gibi değerler de alabilir
mesaj[2:]
# Out:
# 'rhaba'

# %%
#ilk 3 elemanı al sonrasını alma -3 gibi değerler de alabilir
mesaj[:3]
# Out:
# 'Mer'

# %%
#1 den başla 10.cu indeksde dur 2 şer 2 şer atla  
mesaj[1:7:2]
# Out:
# 'ehb'

# %%
#büyük harflerle yazdırmak için kullanılır
mesaj = mesaj.upper()
mesaj
# Out:
# 'MERHABA'

# %%
#küçük harflerle yazdırmak için kullanılır
mesaj = mesaj.lower()
mesaj
# Out:
# 'merhaba'

# %%
#kelimenin başı hangi harflerle başladığını kontrol eder
mesaj.startswith("Me")
# Out:
# False

# %%
#kelimenin sonu hangi harflerle bittiğini kontrol eder
mesaj.endswith("ba")
# Out:
# True

# %%
#verilen girdinin kaç karakterden oluştuğunu söyler
print(len(mesaj))
print(len(mesaj + mesaj1))
# Out:
# 7
# 12

# %%
#fstring değişkenleri yazdırmaya yarar
print("{} {} dedi.".format(isim,mesaj))
print(f"{isim} {mesaj} dedi")
# Out:
# Ali merhaba dedi.
# Ali merhaba dedi

# %%
#normal bölmede küsürat var ;küsüratsız bölme yapmak için kullanılır
16 // 3
# Out:
# 5

# %%
# 3 üzeri 3 vb yazdırmak için kullanılır
3 ** 3
# Out:
# 27

# %%
#Remainder - Kalanını almak 
11 % 3
# Out:
# 2

# %%
#mutlak değere almak için kullanılır
abs(-3*7)
# Out:
# 21

# %%
sayi = 20/7
sayi1 = 3
sayi2 = 5 
sayi3 = "100"
sayi4 = 100

# %%
#sayıları yuvarlamak için kullanılır ; değişkenin yanına "," koyulduktan sonra verilen rakam kadar küsürat gösterilir
round(sayi,2)
# Out:
# 2.86

# %%
#int yuvarlama yapmaz sadece sayıların ondalıklı kısımlarını alır ve küsürat göstermez
int(sayi)
# Out:
# 2

# %%
#float yuvarlama yapmaz ve küsürat gösterir
float(sayi)
# Out:
# 2.857142857142857

# %%
#sayıların ondalıklı kısımlarını alma
sayi - int(sayi)
# Out:
# 0.8571428571428572

# %%
#kontrol etme fonksiyonları ;eşit mi fonksiyonu
sayi1 == sayi2
# Out:
# False

# %%
#eşit değil mi fonksiyonu ;#<= >= < > vb opsiyonel
sayi1 != sayi2
# Out:
# True

# %%
#sayıların aritmetik ortalama hesaplanması için kullanılır
(sayi1 + sayi2)/2
# Out:
# 4.0

# %%
#verilen sayının tipini öğrenmek için kullanılır
type(sayi1)
# Out:
# int

# %%
#string olan sayı ile int olan sayı eşit değildir biri metinken diğeri değer bildirir 
sayi3 == sayi4
# Out:
# False

# %% [markdown]
# #Listeler (listelerde[] köşeli parantez kullanılır)
# #Listelere farklı türlerde (veri tiplerinde) elemanlar konulabilir

# %%
renkler = ["Siyah" , "Beyaz" , "Sarı" , "Mavi" , "Yeşil"]
renkler1 = ["Turuncu" , "Pembe"]
sayilar = [1,2,3,4,5,6,7,8,9]
sayilar1 = [10,20,30,40]

# %%
renkler
# Out:
# ['Siyah', 'Beyaz', 'Sarı', 'Mavi', 'Yeşil']

# %%
#Listelerde de indeks mantığı vardır 
renkler[0]
# Out:
# 'Siyah'

# %%
#Listelerde eleman değiştirilebilir 
sayilar1[0] = 100
sayilar1
# Out:
# [100, 20, 30, 40]

# %%
sayilar1[0] = 100

# %%
#listeye eleman ekleme için append kullanılır
renkler.append("Gri")
renkler
# Out:
# ['Siyah', 'Beyaz', 'Sarı', 'Mavi', 'Yeşil', 'Gri']

# %%
#Listenin en sonundan başka bir araya eklemek istiyorsak insert kullanılır ve indeks verilir
renkler.insert(0,"Kırmızı") 
renkler
# Out:
# ['Kırmızı', 'Siyah', 'Beyaz', 'Sarı', 'Mavi', 'Yeşil', 'Gri']

# %%
#Listeden bir eleman çıkartmak için remove kullanılır 
renkler.remove("Sarı") 
renkler
# Out:
# ['Kırmızı', 'Siyah', 'Beyaz', 'Mavi', 'Yeşil', 'Gri']

# %%
#//Bir listeye başka bir liste eklemek için yine append kullanılır ancak eklenen terimler liste olarak eklenir
#renkler.append(renkler1)
#print(renkler)
#Listeye terim olarak ekleme yapmak için extend kullanılır
renkler.extend(renkler1)
print(renkler)
# Out:
# ['Kırmızı', 'Siyah', 'Beyaz', 'Mavi', 'Yeşil', 'Gri', 'Turuncu', 'Pembe']

# %%
#Listeden bir terimi silmek için pop kullanılır ; silinen elemanı görmek için pop'a str atanır
silinen = renkler.pop(1)
renkler
silinen
# Out:
# 'Siyah'

# %%
#Listeyi sıralamak için sort kullanılır metinleri alfabetik sayıları küçükten büyüğe doğru sıralar
renkler.sort()
print(renkler)
# Out:
# ['Beyaz', 'Gri', 'Kırmızı', 'Mavi', 'Pembe', 'Turuncu', 'Yeşil']

# %%
#listeyi tam tersi şekilde yazdırmak için reverse kullanılır(ikinci reverse normale döndürmek için)
renkler.reverse()
print(renkler)
renkler.reverse()
# Out:
# ['Yeşil', 'Turuncu', 'Pembe', 'Mavi', 'Kırmızı', 'Gri', 'Beyaz']

# %%
#Liste eleman sayısını öğrenmek için len kullanılır
len(renkler)
# Out:
# 7

# %%
renkler.count("Gri")
# Out:
# 1

# %%
#Listeden bir eleman bulmak için index kullanılır ve sayının indeksi alınır
renkler.index("Yeşil")
# Out:
# 6

# %%
#Listeyi sıralamak isterken ana listeyi değiştirmek istemiyorsak sorted kullanılır
renkler2 = sorted(renkler)
renkler2
# Out:
# ['Beyaz', 'Gri', 'Kırmızı', 'Mavi', 'Pembe', 'Turuncu', 'Yeşil']

# %%
#Listedeki en büyük elemanı sormak için (Alfabetik sıra ve sayı değeri olarakta çalışır)
max(renkler)
max(sayilar)
# Out:
# 9

# %%
#Listedeki en küçük elemanı sormak için (Alfabetik sıra ve sayı değeri olarakta çalışır)
min(renkler)
min(sayilar)
# Out:
# 1

# %%
#Verilen string değeri kelime kelime liste olarak kaydeder
Benimİsmim = "Muhammed PALA"
Benimİsmim.split()
# Out:
# ['Muhammed', 'PALA']

# %%
#Listedeki elemanları toplamak için kullanılır
sum(sayilar)
# Out:
# 45

# %%
#Listedeki elemanları döngüyle yazdırır
for i in renkler:
     print(i)
# Out:
# Beyaz
# Gri
# Kırmızı
# Mavi
# Pembe
# Turuncu
# Yeşil

# %%
#Listedeki elemanları numaralandırmak için kullanılır
list(enumerate(renkler))
# Out:
# [(0, 'Beyaz'),
#  (1, 'Gri'),
#  (2, 'Kırmızı'),
#  (3, 'Mavi'),
#  (4, 'Pembe'),
#  (5, 'Turuncu'),
#  (6, 'Yeşil')]

# %%
#Listedeki elemanları numaralandırırken kaçtan başlaması gerektiğini belirlemek için
list(enumerate(renkler,start=1))
# Out:
# [(1, 'Beyaz'),
#  (2, 'Gri'),
#  (3, 'Kırmızı'),
#  (4, 'Mavi'),
#  (5, 'Pembe'),
#  (6, 'Turuncu'),
#  (7, 'Yeşil')]

# %%
#Verilen terim listeye dahil mi? 
print("Sarı" in renkler)
print("Yeşil" in renkler)
# Out:
# False
# True

# %%
print(renkler)
# Out:
# ['Beyaz', 'Gri', 'Kırmızı', 'Mavi', 'Pembe', 'Turuncu', 'Yeşil']

# %%
#Join (birleştirme) methodu elemanların arasına belirlenen işlemleri yapar
print(",".join(renkler))
# Out:
# Beyaz,Gri,Kırmızı,Mavi,Pembe,Turuncu,Yeşil

# %%
#listeyi stringe (tek bir metin dosyası haline) çevirmek 
print(type(renkler))
stringrenkler = " - ".join(renkler)
print(stringrenkler)
print(type(stringrenkler))
# Out:
# <class 'list'>
# Beyaz - Gri - Kırmızı - Mavi - Pembe - Turuncu - Yeşil
# <class 'str'>

# %%
#stringi listeye çevirmek ve split metodu(herhangi bir metni verilen karaktere göre parçalama)
renkler3 = stringrenkler.split("-")
print(renkler3)
# Out:
# ['Beyaz ', ' Gri ', ' Kırmızı ', ' Mavi ', ' Pembe ', ' Turuncu ', ' Yeşil']
