# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 2

# %%
numpyDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigur, benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi1,numpyDizisi2,"g")
benimEksen.plot(numpyDizisi2,numpyDizisi1, color="#C96F23")#farklı renk paletleri de kullanabiliriz
plt.show()

# %%
(yeniFigur, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 2,color="b",linewidth = 8.0)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 3,color="y",linewidth = 2.0)

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4,color="r",linestyle = "-.")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 5,color="r",linestyle = ":")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 6,color="r",linestyle = "--")

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 7,color="#000000",linestyle = "--",marker ="+")

plt.show()

# %% [markdown]
# scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)
plt.show()

# %% [markdown]
# histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([85, 21, 26, 35, 25, 34, 22, 48, 14, 89, 88, 88, 78, 37, 59, 94, 29,
#        55, 97, 16, 35, 19, 48, 33, 36, 41, 18, 55,  7, 29, 28, 66, 54, 35,
#        38, 43, 82, 29, 76, 76, 53, 91, 98, 80,  5, 67,  4, 83, 83, 61])

# %%
plt.hist(yeniDizi)
plt.show()

# %% [markdown]
# boxplot

# %%
plt.boxplot(yeniDizi)
plt.show()
