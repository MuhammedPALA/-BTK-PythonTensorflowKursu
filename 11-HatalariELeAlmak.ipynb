# %% [markdown]
# try & excrpt & else & finally

# %%
while True:
    try:
        benimInt = int(input("Numaranızı giriniz: "))
    except:
        print("Lütfen sayısal bir değer giriniz.")
        continue
    else:
        print("Teşekürler")
        break
    finally:
        print("finally çağırıldı")
# Out:
# Numaranızı giriniz:  r
# Lütfen sayısal bir değer giriniz.
# finally çağırıldı
# Numaranızı giriniz:  10
# Teşekürler
# finally çağırıldı
