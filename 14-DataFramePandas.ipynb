# %%
import numpy as np
import pandas as pd

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 1.11285341,  1.4153674 ,  1.34517053],
#        [ 0.33838653,  0.45382459, -0.48966189],
#        [ 0.17348736, -0.40863567,  0.30490047],
#        [-0.3345633 ,  0.09490013,  0.07662361]])

# %%
#Data Frame serilerin iki boyutlu halidir
dataFrame = pd.DataFrame(data)

# %%
dataFrame
# Out:
#           0         1         2
# 0  1.112853  1.415367  1.345171
# 1  0.338387  0.453825 -0.489662
# 2  0.173487 -0.408636  0.304900
# 3 -0.334563  0.094900  0.076624

# %%
yeniDataFrame = pd.DataFrame(data,index = ["Atil","Zeynep","Atlas","Mehmet"],columns = ["Maas","Yas","Calisma Saati"])

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil    1.112853  1.415367       1.345171
# Zeynep  0.338387  0.453825      -0.489662
# Atlas   0.173487 -0.408636       0.304900
# Mehmet -0.334563  0.094900       0.076624

# %%
#Kolon çağırmak için
yeniDataFrame["Yas"]
# Out:
# Atil      1.415367
# Zeynep    0.453825
# Atlas    -0.408636
# Mehmet    0.094900
# Name: Yas, dtype: float64

# %%
yeniDataFrame["Calisma Saati"]
# Out:
# Atil      1.345171
# Zeynep   -0.489662
# Atlas     0.304900
# Mehmet    0.076624
# Name: Calisma Saati, dtype: float64

# %%
#İki kolon yanyana geldiğinde çift köşeli parantez kullann
yeniDataFrame[["Maas","Yas"]]
# Out:
#             Maas       Yas
# Atil    1.112853  1.415367
# Zeynep  0.338387  0.453825
# Atlas   0.173487 -0.408636
# Mehmet -0.334563  0.094900

# %%
#Satır çağırmak için
yeniDataFrame.loc["Atil"]
# Out:
# Maas             1.112853
# Yas              1.415367
# Calisma Saati    1.345171
# Name: Atil, dtype: float64

# %%
#İndeks olarakta satır çağırabiliriz
yeniDataFrame.iloc[1]
# Out:
# Maas             0.338387
# Yas              0.453825
# Calisma Saati   -0.489662
# Name: Zeynep, dtype: float64

# %%
#Kolon eklerken hazır kolonları kullanabiliriz
yeniDataFrame["Emeklilik Yasi"] = yeniDataFrame["Yas"] + yeniDataFrame["Yas"]

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    1.112853  1.415367       1.345171        2.830735
# Zeynep  0.338387  0.453825      -0.489662        0.907649
# Atlas   0.173487 -0.408636       0.304900       -0.817271
# Mehmet -0.334563  0.094900       0.076624        0.189800

# %%
#Eğer kolon silmek istiyorsak kullanılır ama sadece o hücrede geçerli olur kalıcı değişiklik yapmaz ve eksen belirtmek hata alamamak için gerekli(axis)
yeniDataFrame.drop("Emeklilik Yasi",axis = 1)
# Out:
#             Maas       Yas  Calisma Saati
# Atil    1.112853  1.415367       1.345171
# Zeynep  0.338387  0.453825      -0.489662
# Atlas   0.173487 -0.408636       0.304900
# Mehmet -0.334563  0.094900       0.076624

# %%
yeniDataFrame.drop("Mehmet",axis = 0)
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    1.112853  1.415367       1.345171        2.830735
# Zeynep  0.338387  0.453825      -0.489662        0.907649
# Atlas   0.173487 -0.408636       0.304900       -0.817271

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Atil    1.112853  1.415367       1.345171        2.830735
# Zeynep  0.338387  0.453825      -0.489662        0.907649
# Atlas   0.173487 -0.408636       0.304900       -0.817271
# Mehmet -0.334563  0.094900       0.076624        0.189800

# %%
#Değişiklik kalıcı olsun istiyorsak inplace değeri true verilmeli
yeniDataFrame.drop("Emeklilik Yasi", axis = 1, inplace = True)

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil    1.112853  1.415367       1.345171
# Zeynep  0.338387  0.453825      -0.489662
# Atlas   0.173487 -0.408636       0.304900
# Mehmet -0.334563  0.094900       0.076624

# %%
yeniDataFrame.loc["Atil"]["Calisma Saati"]
# Out:
# np.float64(1.3451705322605232)

# %%
yeniDataFrame.loc["Atil","Calisma Saati"]
# Out:
# np.float64(1.3451705322605232)

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil    1.112853  1.415367       1.345171
# Zeynep  0.338387  0.453825      -0.489662
# Atlas   0.173487 -0.408636       0.304900
# Mehmet -0.334563  0.094900       0.076624

# %%
booleanFrame = yeniDataFrame < 0

# %%
booleanFrame
# Out:
#          Maas    Yas  Calisma Saati
# Atil    False  False          False
# Zeynep  False  False           True
# Atlas   False   True          False
# Mehmet   True  False          False

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil    1.112853  1.415367       1.345171
# Zeynep  0.338387  0.453825      -0.489662
# Atlas   0.173487 -0.408636       0.304900
# Mehmet -0.334563  0.094900       0.076624

# %%
yeniDataFrame[booleanFrame]
# Out:
#             Maas       Yas  Calisma Saati
# Atil         NaN       NaN            NaN
# Zeynep       NaN       NaN      -0.489662
# Atlas        NaN -0.408636            NaN
# Mehmet -0.334563       NaN            NaN

# %%
yeniDataFrame[yeniDataFrame < 0]
# Out:
#             Maas       Yas  Calisma Saati
# Atil         NaN       NaN            NaN
# Zeynep       NaN       NaN      -0.489662
# Atlas        NaN -0.408636            NaN
# Mehmet -0.334563       NaN            NaN

# %%
yeniDataFrame[yeniDataFrame["Calisma Saati"] > 0]
# Out:
#             Maas       Yas  Calisma Saati
# Atil    1.112853  1.415367       1.345171
# Atlas   0.173487 -0.408636       0.304900
# Mehmet -0.334563  0.094900       0.076624

# %%
yeniDataFrame.reset_index()
# Out:
#     index      Maas       Yas  Calisma Saati
# 0    Atil  1.112853  1.415367       1.345171
# 1  Zeynep  0.338387  0.453825      -0.489662
# 2   Atlas  0.173487 -0.408636       0.304900
# 3  Mehmet -0.334563  0.094900       0.076624

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Atil    1.112853  1.415367       1.345171
# Zeynep  0.338387  0.453825      -0.489662
# Atlas   0.173487 -0.408636       0.304900
# Mehmet -0.334563  0.094900       0.076624

# %%
yeniIndexListesi = ["Ati","Zey","Atl","Meh"]

# %%
yeniDataFrame["Yeni Indeks"] = yeniIndexListesi

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati Yeni Indeks
# Atil    1.112853  1.415367       1.345171         Ati
# Zeynep  0.338387  0.453825      -0.489662         Zey
# Atlas   0.173487 -0.408636       0.304900         Atl
# Mehmet -0.334563  0.094900       0.076624         Meh

# %%
yeniDataFrame.set_index("Yeni Indeks")
# Out:
#                  Maas       Yas  Calisma Saati
# Yeni Indeks
# Ati          1.112853  1.415367       1.345171
# Zey          0.338387  0.453825      -0.489662
# Atl          0.173487 -0.408636       0.304900
# Meh         -0.334563  0.094900       0.076624

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati Yeni Indeks
# Atil    1.112853  1.415367       1.345171         Ati
# Zeynep  0.338387  0.453825      -0.489662         Zey
# Atlas   0.173487 -0.408636       0.304900         Atl
# Mehmet -0.334563  0.094900       0.076624         Meh

# %%
yeniDataFrame.set_index("Yeni Indeks",inplace=True)

# %%
yeniDataFrame
# Out:
#                  Maas       Yas  Calisma Saati
# Yeni Indeks
# Ati          1.112853  1.415367       1.345171
# Zey          0.338387  0.453825      -0.489662
# Atl          0.173487 -0.408636       0.304900
# Meh         -0.334563  0.094900       0.076624

# %%
yeniDataFrame.loc["Ati"]
# Out:
# Maas             1.112853
# Yas              1.415367
# Calisma Saati    1.345171
# Name: Ati, dtype: float64

# %%
ilkIndeksler = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
icIndeksler = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
BirlesmisIndeks = list(zip(ilkIndeksler,icIndeksler))

# %%
BirlesmisIndeks
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
BirlesmisIndeks = pd.MultiIndex.from_tuples(BirlesmisIndeks)

# %%
BirlesmisIndeks
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
benimizgiFilmlistem = [[40,"A"],[10,"B"],[30,"C"],[9, "D"],[10, "E"],[11,"F"]]

# %%
cizgiFilmNumpyDizisi = np.array(benimizgiFilmlistem)

# %%
cizgiFilmDataFrame = pd.DataFrame(cizgiFilmNumpyDizisi,index=BirlesmisIndeks,columns=["Yas","Meslek"])

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F

# %%
cizgiFilmDataFrame.loc["Simpson"]
# Out:
#       Yas Meslek
# Homer  40      A
# Bart   10      B
# Marge  30      C

# %%
cizgiFilmDataFrame.loc["South Park"].loc["Kenny"]
# Out:
# Yas       10
# Meslek     E
# Name: Kenny, dtype: object

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F

# %%
cizgiFilmDataFrame.index.names = ["Film Adı","İsim"]

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Film Adı   İsim
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F
