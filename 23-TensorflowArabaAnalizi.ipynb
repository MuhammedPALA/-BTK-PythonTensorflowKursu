# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Bizim excelimizi drive'a aktardık ve dosyası okuması için dosya yoluyla birlikte tanımladık
dataFrame0 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/merc.xlsx')

# %%
dataFrame0.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
#dataFrame e atanan verilerin özelliklerini görmek için
dataFrame0.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
#değerleri sıralamak için kullanılır biz sum fonksiyonu ile direk saydıracağız hepsine tek tek bakamayacağımız için.
dataFrame0.isnull().sum()
#göründüğü üzere verimizde boş veri bulunmuyor
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
#bu kullanım kütüphaneden kaldırılmış ilgili dökümantasyonu okumak için https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751 bu git hub reposundan dökümantasyonu okuyabilirsiniz yeni kullanım (birden fazla yenilik var ama ben sadece birini kullandım) içn sonraki hücreden devam edebilirsiniz.
sbn.distplot(dataFrame0["price"])
# Out:
# /tmp/ipython-input-68954341.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(dataFrame0["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
#ilgili sütunun nasıl dağıldığını görmek için kullanılır
sbn.displot(dataFrame0["price"])

# %%
#countplot sağlıklı tablo oluşturmadığı için kaynaklarda önerilen histplot methodunu kullandık
sbn.histplot(dataFrame0["year"])
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
#vites otomatik mi manuel mi sayısal bir değer olmadığı için korelasyonunu alamadı ve hata verdi bizde sadece numeric değerleri işle dedik ve ısı haritası ekledik okunabilirliği arttırmak amacıyla
dataFrame0.corr(numeric_only=True).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_874bb_row0_col0, #T_874bb_row1_col1, #T_874bb_row2_col2, #T_874bb_row3_col3, #T_874bb_row4_col4, #T_874bb_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_874bb_row0_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_874bb_row0_col2, #T_874bb_row2_col0, #T_874bb_row2_col1, #T_874bb_row3_col4, #T_874bb_row4_col3, #T_874bb_row4_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_874bb_row0_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_874bb_row0_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_874bb_row0_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_874bb_row1_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_874bb_row1_col2, #T_874bb_row5_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_874bb_row1_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_874bb_row1_col4 {
# ...

# %%
#sadece price sütununu aldık ve küçükten büyüğe doğru sıraladık
dataFrame0.corr(numeric_only=True)["price"].sort_values()
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
#verileri gösterek tablo oluşturmak için
sbn.scatterplot(x="mileage", y="price",data=dataFrame0)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
#dataları sıralar büyükten küçüğe sıralamak için ascending i false verdik head normalde 5 değer getirirdi ona da ilk 20 değeri getir dedik
dataFrame0.sort_values("price",ascending=False).head(20)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
dataFrame0.sort_values("price",ascending=True).head(20)
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(dataFrame0)
# Out:
# 13119

# %%
len(dataFrame0) * 0.01
# Out:
# 131.19

# %%
#iloc indekse göre 131. değerden itibaren sıraladık
dataFrame1 = dataFrame0.sort_values("price",ascending = False).iloc[131:]

# %%
dataFrame1.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.displot(dataFrame1["price"])

# %%
dataFrame0.groupby("year").mean(numeric_only=True)["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
dataFrame1.groupby("year").mean(numeric_only=True)["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
dataFrame0 = dataFrame1

# %%
dataFrame0.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame0 = dataFrame0[dataFrame0.year != 1970]

# %%
dataFrame0.groupby("year").mean(numeric_only=True)["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
dataFrame0.head()
# Out:
#       year  price transmission  mileage  tax   mpg  engineSize
# 6177  2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779  2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191  2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727  2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814  2019  64999    Semi-Auto      119  145  40.9         3.0

# %%
dataFrame0 = dataFrame0.drop("transmission",axis=1)

# %%
dataFrame0.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
y = dataFrame0["price"]
x = dataFrame0.drop("price",axis=1).values

# %%
y
# Out:
# 6177     65990
# 5779     65990
# 3191     65980
# 4727     65000
# 8814     64999
#          ...
# 11549     1495
# 12594     1495
# 11765     1490
# 12008     1350
# 11816      650
# Name: price, Length: 12987, dtype: int64

# %%
x
# Out:
# array([[2.01900e+03, 5.07600e+03, 1.50000e+02, 3.04000e+01, 3.00000e+00],
#        [2.02000e+03, 9.99000e+02, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        [2.02000e+03, 3.99900e+03, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        ...,
#        [2.00000e+03, 8.70000e+04, 2.65000e+02, 2.72000e+01, 3.20000e+00],
#        [2.01000e+03, 1.16126e+05, 1.45000e+02, 5.43000e+01, 2.00000e+00],
#        [2.00300e+03, 1.09090e+05, 2.35000e+02, 4.00000e+01, 1.40000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 9090

# %%
len(x_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9090, 5)

# %%
model = Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x = x_train, y = y_train, validation_data=(x_test,y_test),batch_size=250,epochs=300)
# Out:
# Epoch 1/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 680605056.0000 - val_loss: 688093440.0000
# Epoch 2/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 669989888.0000 - val_loss: 688024768.0000
# Epoch 3/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 669217344.0000 - val_loss: 687766336.0000
# Epoch 4/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 673466816.0000 - val_loss: 686928128.0000
# Epoch 5/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 675657856.0000 - val_loss: 684779008.0000
# Epoch 6/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 668800128.0000 - val_loss: 680014848.0000
# Epoch 7/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 654870272.0000 - val_loss: 670482368.0000
# Epoch 8/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 647315200.0000 - val_loss: 653060288.0000
# Epoch 9/300
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 640387840.0000 - val_loss: 624180928.0000
# Epoch 10/300
# ...

# %%
kayıpVerisi = pd.DataFrame(model.history.history)

# %%
kayıpVerisi.head()
# Out:
#           loss     val_loss
# 0  672142528.0  688093440.0
# 1  672102080.0  688024768.0
# 2  671968704.0  687766336.0
# 3  671482304.0  686928128.0
# 4  670124800.0  684779008.0

# %%
kayıpVerisi.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)
# Out:
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
tahminDizisi
# Out:
# array([[25979.377],
#        [22945.049],
#        [24844.822],
#        ...,
#        [22608.629],
#        [19924.021],
#        [25780.213]], dtype=float32)

# %%
mean_absolute_error(y_test,tahminDizisi)
# Out:
# 3280.74609375

# %%
dataFrame0.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test,tahminDizisi,alpha=0.4)
plt.xlabel("Gerçek Değerler")
plt.ylabel("Tahmin Değerleri")
plt.plot(y_test,y_test,"r")

# %%
dataFrame0.iloc[2]
# Out:
# year           2020.0
# price         65980.0
# mileage        3999.0
# tax             145.0
# mpg              28.0
# engineSize        4.0
# Name: 3191, dtype: float64

# %%
yeniArabaSeries = dataFrame0.drop("price",axis=1).iloc[2]

# %%
yeniArabaSeries
# Out:
# year          2020.0
# mileage       3999.0
# tax            145.0
# mpg             28.0
# engineSize       4.0
# Name: 3191, dtype: float64

# %%
type(yeniArabaSeries)
# Out:
# pandas.core.series.Series

# %%
yeniArabaSeries = scaler.transform(yeniArabaSeries.values.reshape(-1,5))

# %%
model.predict(yeniArabaSeries)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# array([[61389.285]], dtype=float32)
