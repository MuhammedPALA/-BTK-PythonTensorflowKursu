# %%
#Bir excel dosyasını okumak için açılan python defteriyle aynı klasörde olması gerekir excel dosyasının
import pandas as pd

# %%
#dataFrame = pd.read_excel("maas.xlsx")

# %%
#dataFrame

# %%
#doluDegerlerDataFrame = dataFrame.dropna()

# %%
#doluDegerlerDataFrame

# %%
#Veri üzerinde Çalıştıktan sonra son halini excel olarak almak için
#doluDegerlerDataFrame.to_excel("yenimaas.xlsx")

# %%
# excel dosyası csv ise aynı mantık 
# read_csv
# to_csv
