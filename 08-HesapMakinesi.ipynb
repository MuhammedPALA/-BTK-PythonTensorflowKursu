# %%
def hesapla(a,b,islem):
    # en başta olsada çalışmıyor çünkü fonksiyon ilk çalıştığında girdi olmadığından ötürü için yanlış girdi olduğunda bu uyarı çıkıyor 
    if islem not in "+-*/": 
        return "Lütfen şu işlemlerden birini seçiniz: +-*/"
    
    if islem == "+":
        return (str(a)+" + "+str(b) + " = " + str(a+b))
    if islem == "-":
        return (str(a)+" - "+str(b) + " = " + str(a-b))
    if islem == "*":
        return (str(a)+" * "+str(b) + " = " + str(a*b))
    if islem == "/":
        return (str(a)+" / "+str(b) + " = " + str(a/b))

#While true sonsuz döngüye soktuğu için kernel interrupt yapıp kernel resstart yapmadan çıkmayı unutma 
while True:
    #kodda bir hata olursa diye try ve except kullanılır
    try:
        a = int(input("ilk sayıyı giriniz: "))
        b = int(input("İkinci sayıyı giriniz: "))
        islem = input("işleminizi seçiniz: +-*/")
        print(hesapla(a,b,islem))
    except:
        print("Lütfen sayıları düzgün giriniz")
# Out:
# ilk sayıyı giriniz:  10
# İkinci sayıyı giriniz:  20
# işleminizi seçiniz: +-*/ g
# Lütfen şu işlemlerden birini seçiniz: +-*/
# ilk sayıyı giriniz:  g
# Lütfen sayıları düzgün giriniz
# ilk sayıyı giriniz:  g
# Lütfen sayıları düzgün giriniz
# ilk sayıyı giriniz:  10
# İkinci sayıyı giriniz:  b
# Lütfen sayıları düzgün giriniz
# ilk sayıyı giriniz:  10
# İkinci sayıyı giriniz:  20
# işleminizi seçiniz: +-*/ h
# Lütfen şu işlemlerden birini seçiniz: +-*/
# ilk sayıyı giriniz:  10
# İkinci sayıyı giriniz:  20
# işleminizi seçiniz: +-*/ 0
# Lütfen şu işlemlerden birini seçiniz: +-*/
# Lütfen sayıları düzgün giriniz
