# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Seriler

# %%
benimSozlugum = {"Atil" : 50, "Zeynep" : 40, "Mehmet" : 30}

# %%
pd.Series(benimSozlugum)
# Out:
# Atil      50
# Zeynep    40
# Mehmet    30
# dtype: int64

# %%
benimYaslarım = [50,40,30]
benimIsimlerim = ["Atil", "Zeynep", "Mehmet "]

# %%
pd.Series(benimYaslarım, benimIsimlerim)
# Out:
# Atil       50
# Zeynep     40
# Mehmet     30
# dtype: int64

# %%
pd.Series(index=benimIsimlerim, data=benimYaslarım )
# Out:
# Atil       50
# Zeynep     40
# Mehmet     30
# dtype: int64

# %%
numpyDizisi = np.array([50,40,30])

# %%
numpyDizisi
# Out:
# array([50, 40, 30])

# %%
pd.Series(numpyDizisi)
# Out:
# 0    50
# 1    40
# 2    30
# dtype: int64

# %%
pd.Series(numpyDizisi,benimIsimlerim)
# Out:
# Atil       50
# Zeynep     40
# Mehmet     30
# dtype: int64

# %%
pd.Series(["Atil","Atlas","Osman"],[1,2,3])
# Out:
# 1     Atil
# 2    Atlas
# 3    Osman
# dtype: object

# %%
yarismaSonucu1 = pd.Series([10,5,20],["Atil","Atlas","Osman"])

# %%
yarismaSonucu1
# Out:
# Atil     10
# Atlas     5
# Osman    20
# dtype: int64

# %%
yarismaSonucu2 = pd.Series([15,10,8],["Atil","Atlas","Osman"])

# %%
yarismaSonucu2["Atlas"]
# Out:
# np.int64(10)

# %%
sonSonuc = yarismaSonucu1 + yarismaSonucu2

# %%
sonSonuc
# Out:
# Atil     25
# Atlas    15
# Osman    28
# dtype: int64

# %%
farkliSeries1 = pd.Series([20,30,40,50],["a","b","c","d"])

# %%
farkliSeries2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
farkliSeries1
# Out:
# a    20
# b    30
# c    40
# d    50
# dtype: int64

# %%
farkliSeries2
# Out:
# a    10
# c     5
# f     3
# g     1
# dtype: int64

# %%
farkliSeries1 + farkliSeries2
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
